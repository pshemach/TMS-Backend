# %%
# %cd ..
# Out:
# c:\Users\HP\OneDrive - University of Moratuwa\Desktop\TMS-Project\TMS-Backend

# %%
from sqlalchemy.orm import Session, scoped_session
from src.database.database import SessionLocal
from src.database import database, models

# %%
db = SessionLocal()

# %%
q = db.query(models.JobStop).join(models.JobRoute).filter(
        models.JobRoute.vehicle_id == 2,
        models.JobStop.shop.brand!= 'depot' # exclude depot
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\HP\OneDrive - University of Moratuwa\Desktop\TMS-Project\TMS-Backend\.venv\Lib\site-packages\sqlalchemy\orm\attributes.py:475, in QueryableAttribute.__getattr__(self, key)
#     474 try:
# --> 475     return getattr(self.comparator, key)
#     476 except AttributeError as err:
#
# File c:\Users\HP\OneDrive - University of Moratuwa\Desktop\TMS-Project\TMS-Backend\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:1416, in MemoizedSlots.__getattr__(self, key)
#    1415 else:
# -> 1416     return self._fallback_getattr(key)
#
# File c:\Users\HP\OneDrive - University of Moratuwa\Desktop\TMS-Project\TMS-Backend\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:1385, in MemoizedSlots._fallback_getattr(self, key)
#    1384 def _fallback_getattr(self, key):
# -> 1385     raise AttributeError(key)
#
# AttributeError: brand
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 3
#       1 q = db.query(models.JobStop).join(models.JobRoute).filter(
#       2         models.JobRoute.vehicle_id == 2,
# ----> 3         models.JobStop.shop.brand!= 'depot' # exclude depot
#       4     )
#
# File c:\Users\HP\OneDrive - University of Moratuwa\Desktop\TMS-Project\TMS-Backend\.venv\Lib\site-packages\sqlalchemy\orm\attributes.py:477, in QueryableAttribute.__getattr__(self, key)
#     475     return getattr(self.comparator, key)
#     476 except AttributeError as err:
# --> 477     raise AttributeError(
#     478         "Neither %r object nor %r object associated with %s "
#     479         "has an attribute %r"
#     480         % (
#     481             type(self).__name__,
#     482             type(self.comparator).__name__,
#     483             self,
#     484             key,
#     485         )
#     486     ) from err
#
# AttributeError: Neither 'InstrumentedAttribute' object nor 'Comparator' object associated with JobStop.shop has an attribute 'brand'

# %%
q = q.filter(models.JobRoute.job_id == 10)
q

# %%
for item in q:
    print(item.route_id)
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8

# %%
for item in q:
    print(item.shop.brand)
# Out:
# depot
# Arpico
# Cargills
# Cargills
# Arpico
# Cargills
# Cargills
# depot

# %%
visits = q.order_by(models.JobStop.sequence).all()

# %%
visits
# Out:
# []
